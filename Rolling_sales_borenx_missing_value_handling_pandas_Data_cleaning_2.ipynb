# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijay2000kumar/Google_Coolab_files/blob/main/Rolling_sales_borenx_missing_value_handling_pandas_Data_cleaning_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas pakage alias name pd
import pandas as pd

# %%
#to read the excel or other file we use pd.read_
df= pd.read_excel("/content/rollingsales_bronx.xlsx")

# %%
# to see first five rows values
df.head()
# Out:
#   Bronx Rolling Sales.  All Sales From July 2022 - June 2023    Unnamed: 1  \
# 0  For sales prior to the Final Roll, Neighborhoo...                   NaN
# 1  Building Class Category is based on Building C...                   NaN
# 2  Note: Condominium and cooperative sales are on...                   NaN
# 3                                            BOROUGH          NEIGHBORHOOD
# 4                                                  2              BATHGATE
#
#                 Unnamed: 2            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                      NaN                   NaN        NaN        NaN
# 1                      NaN                   NaN        NaN        NaN
# 2                      NaN                   NaN        NaN        NaN
# 3  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT      BLOCK        LOT
# 4  01 ONE FAMILY DWELLINGS                     1       2905         26
#
#   Unnamed: 6                 Unnamed: 7              Unnamed: 8  \
# 0        NaN                        NaN                     NaN
# 1        NaN                        NaN                     NaN
# 2        NaN                        NaN                     NaN
# 3   EASEMENT  BUILDING CLASS AT PRESENT                 ADDRESS
# 4        NaN                         A9  1667 WASHINGTON AVENUE
#
#          Unnamed: 9  ...        Unnamed: 11       Unnamed: 12  Unnamed: 13  \
# 0               NaN  ...                NaN               NaN          NaN
# 1               NaN  ...                NaN               NaN          NaN
# 2               NaN  ...                NaN               NaN          NaN
# 3  APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS
# 4               NaN  ...                  1                 0            1
#
#         Unnamed: 14        Unnamed: 15 Unnamed: 16                Unnamed: 17  \
# 0               NaN                NaN         NaN                        NaN
# 1               NaN                NaN         NaN                        NaN
# 2               NaN                NaN         NaN                        NaN
# 3  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE
# 4              4750               3167        1899                          1
#
#                       Unnamed: 18 PTS Sales Data as of 07/12/2023  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3  BUILDING CLASS AT TIME OF SALE                      SALE PRICE
# 4                              A9                          980000
#
#            Unnamed: 20
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3            SALE DATE
# 4  2022-09-08 00:00:00
#
# [5 rows x 21 columns]

# %%
df1=df.drop(df.index[:3], axis=0)

# %%
df1
# Out:
#      Bronx Rolling Sales.  All Sales From July 2022 - June 2023    Unnamed: 1  \
# 3                                               BOROUGH          NEIGHBORHOOD
# 4                                                     2              BATHGATE
# 5                                                     2              BATHGATE
# 6                                                     2              BATHGATE
# 7                                                     2              BATHGATE
# ...                                                 ...                   ...
# 6044                                                  2              WOODLAWN
# 6045                                                  2              WOODLAWN
# 6046                                                  2              WOODLAWN
# 6047                                                  2              WOODLAWN
# 6048                                                  2              WOODLAWN
#
#                                     Unnamed: 2            Unnamed: 3  \
# 3                      BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT
# 4                      01 ONE FAMILY DWELLINGS                     1
# 5                      01 ONE FAMILY DWELLINGS                     1
# 6                      01 ONE FAMILY DWELLINGS                     1
# 7                      01 ONE FAMILY DWELLINGS                     1
# ...                                        ...                   ...
# 6044            10 COOPS - ELEVATOR APARTMENTS                     2
# 6045                        22 STORE BUILDINGS                     4
# 6046                        22 STORE BUILDINGS                     4
# 6047                        22 STORE BUILDINGS                     4
# 6048  35 INDOOR PUBLIC AND CULTURAL FACILITIES                     4
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6                 Unnamed: 7  \
# 3         BLOCK        LOT   EASEMENT  BUILDING CLASS AT PRESENT
# 4          2905         26        NaN                         A9
# 5          3028         24        NaN                         A1
# 6          3030         65        NaN                         A1
# 7          3030         66        NaN                         A1
# ...         ...        ...        ...                        ...
# 6044       3398         97        NaN                         D4
# 6045       3363         17        NaN                         K2
# 6046       3380         46        NaN                         K1
# 6047       3380         46        NaN                         K1
# 6048       3380         54        NaN                         P8
#
#                    Unnamed: 8        Unnamed: 9  ...        Unnamed: 11  \
# 3                     ADDRESS  APARTMENT NUMBER  ...  RESIDENTIAL UNITS
# 4      1667 WASHINGTON AVENUE               NaN  ...                  1
# 5       410 EAST 179TH STREET               NaN  ...                  1
# 6            4455 PARK AVENUE               NaN  ...                  1
# 7            4453 PARK AVENUE               NaN  ...                  1
# ...                       ...               ...  ...                ...
# 6044  4295 WEBSTER AVENUE, 4K               NaN  ...                NaN
# 6045        23 E 233RD STREET               NaN  ...                  0
# 6046      4361 KATONAH AVENUE               NaN  ...                  0
# 6047      4361 KATONAH AVENUE               NaN  ...                  0
# 6048      4351 KATONAH AVENUE               NaN  ...                  0
#
#            Unnamed: 12  Unnamed: 13       Unnamed: 14        Unnamed: 15  \
# 3     COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET
# 4                    0            1              4750               3167
# 5                    0            1              1842               2048
# 6                    0            1              1622               1587
# 7                    0            1              1646               1497
# ...                ...          ...               ...                ...
# 6044               NaN          NaN               NaN                NaN
# 6045                 1            1              2537               2635
# 6046                 1            1              9699               3400
# 6047                 1            1              9699               3400
# 6048                 1            1              3121               2520
#
#      Unnamed: 16                Unnamed: 17                     Unnamed: 18  \
# 3     YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE
# 4           1899                          1                              A9
# 5           1901                          1                              A1
# 6           1899                          1                              A1
# 7           1899                          1                              A1
# ...          ...                        ...                             ...
# 6044        1957                          2                              D4
# 6045        1925                          4                              K2
# 6046        1970                          4                              K1
# 6047        1970                          4                              K1
# 6048        1970                          4                              P8
#
#      PTS Sales Data as of 07/12/2023          Unnamed: 20
# 3                         SALE PRICE            SALE DATE
# 4                             980000  2022-09-08 00:00:00
# 5                             655000  2022-11-01 00:00:00
# 6                             520000  2022-10-26 00:00:00
# 7                             215000  2023-04-18 00:00:00
# ...                              ...                  ...
# 6044                          114500  2023-03-01 00:00:00
# 6045                               0  2022-12-13 00:00:00
# 6046                               0  2022-12-12 00:00:00
# 6047                               0  2023-04-17 00:00:00
# 6048                               0  2023-04-17 00:00:00
#
# [6046 rows x 21 columns]

# %%
#we have to read again excel file to skip first four rows
df=pd.read_excel("/content/rollingsales_bronx.xlsx", skiprows=4, header=0)
df
# Out:
#       BOROUGH NEIGHBORHOOD                   BUILDING CLASS CATEGORY  \
# 0           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 1           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 2           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 3           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 4           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# ...       ...          ...                                       ...
# 6040        2     WOODLAWN            10 COOPS - ELEVATOR APARTMENTS
# 6041        2     WOODLAWN                        22 STORE BUILDINGS
# 6042        2     WOODLAWN                        22 STORE BUILDINGS
# 6043        2     WOODLAWN                        22 STORE BUILDINGS
# 6044        2     WOODLAWN  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#      TAX CLASS AT PRESENT  BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT  \
# 0                       1   2905   26       NaN                        A9
# 1                       1   3028   24       NaN                        A1
# 2                       1   3030   65       NaN                        A1
# 3                       1   3030   66       NaN                        A1
# 4                       1   3035   52       NaN                        A1
# ...                   ...    ...  ...       ...                       ...
# 6040                    2   3398   97       NaN                        D4
# 6041                    4   3363   17       NaN                        K2
# 6042                    4   3380   46       NaN                        K1
# 6043                    4   3380   46       NaN                        K1
# 6044                    4   3380   54       NaN                        P8
#
#                       ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0      1667 WASHINGTON AVENUE              NaN  ...                1.0
# 1       410 EAST 179TH STREET              NaN  ...                1.0
# 2            4455 PARK AVENUE              NaN  ...                1.0
# 3            4453 PARK AVENUE              NaN  ...                1.0
# 4         461 EAST 178 STREET              NaN  ...                1.0
# ...                       ...              ...  ...                ...
# 6040  4295 WEBSTER AVENUE, 4K              NaN  ...                NaN
# 6041        23 E 233RD STREET              NaN  ...                0.0
# 6042      4361 KATONAH AVENUE              NaN  ...                0.0
# 6043      4361 KATONAH AVENUE              NaN  ...                0.0
# 6044      4351 KATONAH AVENUE              NaN  ...                0.0
#
#       COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                  0.0          1.0            4750.0             3167.0
# 1                  0.0          1.0            1842.0             2048.0
# 2                  0.0          1.0            1622.0             1587.0
# 3                  0.0          1.0            1646.0             1497.0
# 4                  0.0          1.0            1782.0             1548.0
# ...                ...          ...               ...                ...
# 6040               NaN          NaN               NaN                NaN
# 6041               1.0          1.0            2537.0             2635.0
# 6042               1.0          1.0            9699.0             3400.0
# 6043               1.0          1.0            9699.0             3400.0
# 6044               1.0          1.0            3121.0             2520.0
#
#       YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0         1899.0                          1                              A9
# 1         1901.0                          1                              A1
# 2         1899.0                          1                              A1
# 3         1899.0                          1                              A1
# 4         1899.0                          1                              A1
# ...          ...                        ...                             ...
# 6040      1957.0                          2                              D4
# 6041      1925.0                          4                              K2
# 6042      1970.0                          4                              K1
# 6043      1970.0                          4                              K1
# 6044      1970.0                          4                              P8
#
#      SALE PRICE  SALE DATE
# 0        980000 2022-09-08
# 1        655000 2022-11-01
# 2        520000 2022-10-26
# 3        215000 2023-04-18
# 4             0 2023-04-14
# ...         ...        ...
# 6040     114500 2023-03-01
# 6041          0 2022-12-13
# 6042          0 2022-12-12
# 6043          0 2023-04-17
# 6044          0 2023-04-17
#
# [6045 rows x 21 columns]

# %%
# see
df.head()
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   2905
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3028
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 3        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3030
# 4        2     BATHGATE  01 ONE FAMILY DWELLINGS                    1   3035
#
#    LOT  EASEMENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0   26       NaN                        A9  1667 WASHINGTON AVENUE
# 1   24       NaN                        A1   410 EAST 179TH STREET
# 2   65       NaN                        A1        4455 PARK AVENUE
# 3   66       NaN                        A1        4453 PARK AVENUE
# 4   52       NaN                        A1     461 EAST 178 STREET
#
#   APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0              NaN  ...                1.0               0.0          1.0
# 1              NaN  ...                1.0               0.0          1.0
# 2              NaN  ...                1.0               0.0          1.0
# 3              NaN  ...                1.0               0.0          1.0
# 4              NaN  ...                1.0               0.0          1.0
#
#    LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0            4750.0             3167.0      1899.0                          1
# 1            1842.0             2048.0      1901.0                          1
# 2            1622.0             1587.0      1899.0                          1
# 3            1646.0             1497.0      1899.0                          1
# 4            1782.0             1548.0      1899.0                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A9     980000 2022-09-08
# 1                              A1     655000 2022-11-01
# 2                              A1     520000 2022-10-26
# 3                              A1     215000 2023-04-18
# 4                              A1          0 2023-04-14
#
# [5 rows x 21 columns]

# %%
#to see last row values
df.tail()
# Out:
#       BOROUGH NEIGHBORHOOD                   BUILDING CLASS CATEGORY  \
# 6040        2     WOODLAWN            10 COOPS - ELEVATOR APARTMENTS
# 6041        2     WOODLAWN                        22 STORE BUILDINGS
# 6042        2     WOODLAWN                        22 STORE BUILDINGS
# 6043        2     WOODLAWN                        22 STORE BUILDINGS
# 6044        2     WOODLAWN  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#      TAX CLASS AT PRESENT  BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT  \
# 6040                    2   3398   97       NaN                        D4
# 6041                    4   3363   17       NaN                        K2
# 6042                    4   3380   46       NaN                        K1
# 6043                    4   3380   46       NaN                        K1
# 6044                    4   3380   54       NaN                        P8
#
#                       ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 6040  4295 WEBSTER AVENUE, 4K              NaN  ...                NaN
# 6041        23 E 233RD STREET              NaN  ...                0.0
# 6042      4361 KATONAH AVENUE              NaN  ...                0.0
# 6043      4361 KATONAH AVENUE              NaN  ...                0.0
# 6044      4351 KATONAH AVENUE              NaN  ...                0.0
#
#       COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 6040               NaN          NaN               NaN                NaN
# 6041               1.0          1.0            2537.0             2635.0
# 6042               1.0          1.0            9699.0             3400.0
# 6043               1.0          1.0            9699.0             3400.0
# 6044               1.0          1.0            3121.0             2520.0
#
#       YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 6040      1957.0                          2                              D4
# 6041      1925.0                          4                              K2
# 6042      1970.0                          4                              K1
# 6043      1970.0                          4                              K1
# 6044      1970.0                          4                              P8
#
#      SALE PRICE  SALE DATE
# 6040     114500 2023-03-01
# 6041          0 2022-12-13
# 6042          0 2022-12-12
# 6043          0 2023-04-17
# 6044          0 2023-04-17
#
# [5 rows x 21 columns]

# %%
#to see the number of rews and columns
df.shape
# Out:
# (6045, 21)

# %%
#to see statistics informations
df.describe()
# Out:
#        BOROUGH        BLOCK          LOT  EASEMENT      ZIP CODE  \
# count   6045.0  6045.000000  6045.000000       0.0   6045.000000
# mean       2.0  4286.932837   303.329032       NaN  10463.694789
# std        0.0  1057.807971   765.118278       NaN     16.170316
# min        2.0  2265.000000     1.000000       NaN  10123.000000
# 25%        2.0  3348.000000    21.000000       NaN  10461.000000
# 50%        2.0  4270.000000    48.000000       NaN  10465.000000
# 75%        2.0  5347.000000   123.000000       NaN  10469.000000
# max        2.0  5955.000000  9100.000000       NaN  10475.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# count        4888.000000       4421.000000  4924.000000      4.385000e+03
# mean            3.510843          0.192490     3.658002      1.248966e+04
# std            23.814067          0.980026    23.820355      2.150559e+05
# min             0.000000          0.000000     0.000000      5.200000e+01
# 25%             1.000000          0.000000     1.000000      2.200000e+03
# 50%             2.000000          0.000000     2.000000      2.500000e+03
# 75%             2.000000          0.000000     2.000000      3.633000e+03
# max          1019.000000         33.000000  1019.000000      5.799632e+06
#
#        GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE
# count       4.385000e+03  5412.000000                6045.000000  6.045000e+03
# mean        6.926853e+03  1944.833149                   1.502399  9.255248e+05
# std         6.388088e+04    28.253526                   0.803823  4.066091e+06
# min         0.000000e+00  1886.000000                   1.000000  0.000000e+00
# 25%         1.560000e+03  1925.000000                   1.000000  0.000000e+00
# 50%         2.142000e+03  1940.000000                   1.000000  3.350000e+05
# 75%         3.036000e+03  1961.000000                   2.000000  7.300000e+05
# max         1.598812e+06  2022.000000                   4.000000  1.037419e+08

# %%
# to see metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6045 entries, 0 to 6044
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         6045 non-null   int64
#  1   NEIGHBORHOOD                    6045 non-null   object
#  2   BUILDING CLASS CATEGORY         6045 non-null   object
#  3   TAX CLASS AT PRESENT            6045 non-null   object
#  4   BLOCK                           6045 non-null   int64
#  5   LOT                             6045 non-null   int64
#  6   EASEMENT                        0 non-null      float64
#  7   BUILDING CLASS AT PRESENT       6045 non-null   object
#  8   ADDRESS                         6045 non-null   object
#  9   APARTMENT NUMBER                538 non-null    object
#  10  ZIP CODE                        6045 non-null   int64
#  11  RESIDENTIAL UNITS               4888 non-null   float64
#  12  COMMERCIAL UNITS                4421 non-null   float64
#  13  TOTAL UNITS                     4924 non-null   float64
#  14  LAND SQUARE FEET                4385 non-null   float64
#  15  GROSS SQUARE FEET               4385 non-null   float64
#  16  YEAR BUILT                      5412 non-null   float64
#  17  TAX CLASS AT TIME OF SALE       6045 non-null   int64
#  18  BUILDING CLASS AT TIME OF SALE  6045 non-null   object
#  19  SALE PRICE                      6045 non-null   int64
#  20  SALE DATE                       6045 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(6), object(7)
# memory usage: 991.9+ KB

# %%
# to see columns name
df.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASEMENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
#to write in title case name of columns
df.columns=df.columns.str.title()

# %%
df.columns
# Out:
# Index(['Borough', 'Neighborhood', 'Building Class Category',
#        'Tax Class At Present', 'Block', 'Lot', 'Easement',
#        'Building Class At Present', 'Address', 'Apartment Number', 'Zip Code',
#        'Residential Units', 'Commercial Units', 'Total Units',
#        'Land Square Feet', 'Gross Square Feet', 'Year Built',
#        'Tax Class At Time Of Sale', 'Building Class At Time Of Sale',
#        'Sale Price', 'Sale Date'],
#       dtype='object')

# %%
# replace the whitespace names with underscore("","_")
df.columns=df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['Borough', 'Neighborhood', 'Building_Class_Category',
#        'Tax_Class_At_Present', 'Block', 'Lot', 'Easement',
#        'Building_Class_At_Present', 'Address', 'Apartment_Number', 'Zip_Code',
#        'Residential_Units', 'Commercial_Units', 'Total_Units',
#        'Land_Square_Feet', 'Gross_Square_Feet', 'Year_Built',
#        'Tax_Class_At_Time_Of_Sale', 'Building_Class_At_Time_Of_Sale',
#        'Sale_Price', 'Sale_Date'],
#       dtype='object')

# %%
# to check columns name and their datatype according to which type values they contain
df.dtypes
# Out:
# Borough                                    int64
# Neighborhood                              object
# Building_Class_Category                   object
# Tax_Class_At_Present                      object
# Block                                      int64
# Lot                                        int64
# Easement                                 float64
# Building_Class_At_Present                 object
# Address                                   object
# Apartment_Number                          object
# Zip_Code                                   int64
# Residential_Units                        float64
# Commercial_Units                         float64
# Total_Units                              float64
# Land_Square_Feet                         float64
# Gross_Square_Feet                        float64
# Year_Built                               float64
# Tax_Class_At_Time_Of_Sale                  int64
# Building_Class_At_Time_Of_Sale            object
# Sale_Price                                 int64
# Sale_Date                         datetime64[ns]
# dtype: object

# %%
# after observation we have to convert Year_Built columns data type float to object type
df['Year_Built']=df['Year_Built'].astype("str")

# %%
df.dtypes
# Out:
# Borough                                    int64
# Neighborhood                              object
# Building_Class_Category                   object
# Tax_Class_At_Present                      object
# Block                                      int64
# Lot                                        int64
# Easement                                 float64
# Building_Class_At_Present                 object
# Address                                   object
# Apartment_Number                          object
# Zip_Code                                   int64
# Residential_Units                        float64
# Commercial_Units                         float64
# Total_Units                              float64
# Land_Square_Feet                         float64
# Gross_Square_Feet                        float64
# Year_Built                                object
# Tax_Class_At_Time_Of_Sale                  int64
# Building_Class_At_Time_Of_Sale            object
# Sale_Price                                 int64
# Sale_Date                         datetime64[ns]
# dtype: object

# %% [markdown]
# All data types appear in order except the Year_Built column, which should be categorical. While this has no major significance, when we aggregate these columns Year_Built will likely be included.

# %%
# import seaborn pakage and matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#extract the column names
cols = df.columns

#plot a heatmap of missing values with seaborn
plt.figure(figsize = (10,5))
sns.heatmap(df[cols].isnull())
# Out:
# <Axes: >

# %% [markdown]
# The first line of code, cols = df.columns, extracts the column names from the DataFrame and stores them in a list called cols.
#
# The second line of code, plt.figure(figsize = (10,5)), creates a new figure with a width of 10 inches and a height of 5 inches.
#
# The third line of code, sns.heatmap(df[cols].isnull()), plots a heatmap of the missing values in the DataFrame. The sns.heatmap() function takes a DataFrame as input and returns a heatmap of the missing values. The isnull() method of the DataFrame returns a Boolean DataFrame that indicates whether each value in the DataFrame is missing or not.
#
# The heatmap will show the missing values in the DataFrame as white cells. The darker the cell, the more missing values there are in that column.

# %%
#Get the percentage of missing values in each column
missing_pct = round(df.isnull().sum()/len(df) * 100, 1)
print(missing_pct)
# Out:
# Borough                             0.0
# Neighborhood                        0.0
# Building_Class_Category             0.0
# Tax_Class_At_Present                0.0
# Block                               0.0
# Lot                                 0.0
# Easement                          100.0
# Building_Class_At_Present           0.0
# Address                             0.0
# Apartment_Number                   91.1
# Zip_Code                            0.0
# Residential_Units                  19.1
# Commercial_Units                   26.9
# Total_Units                        18.5
# Land_Square_Feet                   27.5
# Gross_Square_Feet                  27.5
# Year_Built                          0.0
# Tax_Class_At_Time_Of_Sale           0.0
# Building_Class_At_Time_Of_Sale      0.0
# Sale_Price                          0.0
# Sale_Date                           0.0
# dtype: float64

# %% [markdown]
# The code you provided will calculate the percentage of missing values in each column of a Pandas DataFrame df and print the results. The output of the code will be a Series with the percentage of missing values in each column, rounded to 1 decimal place.

# %%
# we can drop column Easement and Apartment_Number
#df.drop["Easement","Apartment_Number"].head()

# %%
#columns with more than 30% missing values
drop_cols = missing_pct[missing_pct > 30].index

# %%
#We can drop these columns with greater than 30 percent missing values
df_new = df.drop(columns = drop_cols)

# %%
#Extract columns with mising values between 1 and 30%
replace_cols = missing_pct[(missing_pct > 0) & (missing_pct < 30)].index

# %%
#Iterate to replace missing values
for col in replace_cols:
    #if column is year built we replace with median otherwise the mean
    if col == "Year_Built":
        df_new.fillna(df_new[col].median(), inplace = True)
    else:
        mean_value = df_new[col].mean()
        df_new.fillna(mean_value, inplace = True)

# %%
 #preview for missing values
df_new.isnull().sum()
# Out:
# Borough                           0
# Neighborhood                      0
# Building_Class_Category           0
# Tax_Class_At_Present              0
# Block                             0
# Lot                               0
# Building_Class_At_Present         0
# Address                           0
# Zip_Code                          0
# Residential_Units                 0
# Commercial_Units                  0
# Total_Units                       0
# Land_Square_Feet                  0
# Gross_Square_Feet                 0
# Year_Built                        0
# Tax_Class_At_Time_Of_Sale         0
# Building_Class_At_Time_Of_Sale    0
# Sale_Price                        0
# Sale_Date                         0
# dtype: int64
