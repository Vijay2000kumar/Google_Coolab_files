# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijay2000kumar/Google_Coolab_files/blob/main/BL_Flicker_Images_book_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import required lilbrairies
import pandas as pd
import numpy as np

# %%
#read the csv file
df=pd.read_csv("https://raw.githubusercontent.com/mramshaw/Data-Cleaning/master/Datasets/BL-Flickr-Images-Book.csv")

# %%
#to see ,we can use sample(), df.head(),df.tail()
df
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# 0            1879 [1878]         S. Tinsley & Co.
# 1                   1868             Virtue & Co.
# 2                   1869    Bradbury, Evans & Co.
# 3                   1851            James Darling
# 4                   1857     Wertheim & Macintosh
# ...                  ...                      ...
# 8282                1838                      NaN
# 8283            1831, 32          M. Mozley & Son
# 8284           [1806]-22  T. Cadell and W. Davies
# 8285                1834         Mackenzie & Dent
# 8286             1834-43                      NaN
#
#                                                   Title  \
# 0                     Walter Forbes. [A novel.] By A. A
# 1     All for Greed. [A novel. The dedication signed...
# 2     Love the Avenger. By the author of “All for Gr...
# 3     Welsh Sketches, chiefly ecclesiastical, to the...
# 4     [The World in which I live, and my place in it...
# ...                                                 ...
# 8282  The Parochial History of Cornwall, founded on,...
# 8283  The History and Gazetteer of the County of Der...
# 8284  Magna Britannia; being a concise topographical...
# 8285  An historical, topographical and descriptive v...
# 8286  Collectanea Topographica et Genealogica. [Firs...
#
#                                                  Author  \
# 0                                                 A. A.
# 1                                             A., A. A.
# 2                                             A., A. A.
# 3                                             A., E. S.
# 4                                             A., E. S.
# ...                                                 ...
# 8282                 GIDDY, afterwards GILBERT, Davies.
# 8283                         GLOVER, Stephen - of Derby
# 8284  LYSONS, Daniel - M.A., F.R.S., and LYSONS (Sam...
# 8285                              Mackenzie, E. (Eneas)
# 8286                                                NaN
#
#                                            Contributors  Corporate Author  \
# 0                                       FORBES, Walter.               NaN
# 1          BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2          BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3                           Appleyard, Ernest Silvanus.               NaN
# 4                                   BROOME, John Henry.               NaN
# ...                                                 ...               ...
# 8282  BOASE, Henry Samuel.|HALS, William.|LYSONS, Da...               NaN
# 8283                                     NOBLE, Thomas.               NaN
# 8284           GREGSON, Matthew.|LYSONS, Samuel - F.R.S               NaN
# 8285                               ROSS, M. - of Durham               NaN
# 8286            BANDINEL, Bulkeley.|Nichols, John Gough               NaN
#
#       Corporate Contributors Former owner  Engraver Issuance type  \
# 0                        NaN          NaN       NaN   monographic
# 1                        NaN          NaN       NaN   monographic
# 2                        NaN          NaN       NaN   monographic
# 3                        NaN          NaN       NaN   monographic
# 4                        NaN          NaN       NaN   monographic
# ...                      ...          ...       ...           ...
# 8282                     NaN          NaN       NaN   monographic
# 8283                     NaN          NaN       NaN   monographic
# 8284                     NaN          NaN       NaN   monographic
# 8285                     NaN          NaN       NaN   monographic
# 8286                     NaN          NaN       NaN    continuing
#
#                                              Flickr URL  \
# 0     http://www.flickr.com/photos/britishlibrary/ta...
# 1     http://www.flickr.com/photos/britishlibrary/ta...
# 2     http://www.flickr.com/photos/britishlibrary/ta...
# 3     http://www.flickr.com/photos/britishlibrary/ta...
# 4     http://www.flickr.com/photos/britishlibrary/ta...
# ...                                                 ...
# 8282  http://www.flickr.com/photos/britishlibrary/ta...
# 8283  http://www.flickr.com/photos/britishlibrary/ta...
# 8284  http://www.flickr.com/photos/britishlibrary/ta...
# 8285  http://www.flickr.com/photos/britishlibrary/ta...
# 8286  http://www.flickr.com/photos/britishlibrary/ta...
#
#                                              Shelfmarks
# 0                     British Library HMNTS 12641.b.30.
# 1                     British Library HMNTS 12626.cc.2.
# 2                     British Library HMNTS 12625.dd.1.
# 3                   British Library HMNTS 10369.bbb.15.
# 4                      British Library HMNTS 9007.d.28.
# ...                                                 ...
# 8282  British Library HMNTS|British Library HMNTS 10...
# 8283  British Library HMNTS|British Library HMNTS 10...
# 8284  British Library HMNTS|British Library HMNTS 19...
# 8285  British Library HMNTS|British Library HMNTS 10...
# 8286  British Library HMNTS|British Library HMNTS 79...
#
# [8287 rows x 15 columns]

# %%
df.sample(5)
# Out:
#       Identifier                                  Edition Statement  \
# 6105     3008060  The second edition; with corrections, consider...
# 3746     1819998                                                NaN
# 6397     3136980  A new edition, with engravings on wood ... fro...
# 1911      854720                                                NaN
# 4530     2265444                                                NaN
#
#                               Place of Publication Date of Publication  \
# 6105                                        London                1805
# 3746  pp. xvi. 159. G. Redway: London, 1898 [1897]                 NaN
# 6397                                  London, 1810                 NaN
# 1911                                       Bristol                1834
# 4530                                         Paris             1872-75
#
#           Publisher                                              Title  \
# 6105            NaN       [A General View of the writings of Linnæus.]
# 3746            NaN  Rhymes of Ironquill. Selected and arranged by ...
# 6397            NaN  [The pleasures of memory, and other poems. By ...
# 1911  Mirror Office  Antiquities of Bristow in the Middle Centuries...
# 4530            NaN  Paris historique, anecdotique et pittoresque. ...
#
#                                              Author  \
# 6105                             PULTENEY, Richard.
# 3746                                            NaN
# 6397                      ROGERS, Samuel - the Poet
# 1911  DALLAWAY, James - B.M., Prebendary of Ferring
# 4530                                LOUFT, Charles.
#
#                                     Contributors  Corporate Author  \
# 6105                      MATON, William George.               NaN
# 3746             HAMMERTON, John Alexander - Sir               NaN
# 6397                           STOTHARD, Thomas.               NaN
# 1911                          CANYNGES, William.               NaN
# 4530  CLERGET, Hubert.|VERNIER, Charles - Artist               NaN
#
#       Corporate Contributors Former owner  Engraver Issuance type  \
# 6105                     NaN          NaN       NaN   monographic
# 3746                     NaN          NaN       NaN   monographic
# 6397                     NaN          NaN       NaN   monographic
# 1911                     NaN          NaN       NaN   monographic
# 4530                     NaN          NaN       NaN   monographic
#
#                                              Flickr URL  \
# 6105  http://www.flickr.com/photos/britishlibrary/ta...
# 3746  http://www.flickr.com/photos/britishlibrary/ta...
# 6397  http://www.flickr.com/photos/britishlibrary/ta...
# 1911  http://www.flickr.com/photos/britishlibrary/ta...
# 4530  http://www.flickr.com/photos/britishlibrary/ta...
#
#                                              Shelfmarks
# 6105                    British Library HMNTS 983.g.23.
# 3746                 British Library HMNTS 011652.g.60.
# 6397  British Library HMNTS 11645.bbb.32.|British Li...
# 1911  British Library HMNTS 010368.i.94.|British Lib...
# 4530                  British Library HMNTS 10168.i.10.

# %%
df.tail(10)
# Out:
#       Identifier Edition Statement Place of Publication Date of Publication  \
# 8277     4117751               NaN             New York                1882
# 8278     4117752               NaN               London        1883, [1884]
# 8279     4156359               NaN             New York           1898-1912
# 8280     4157746               NaN               London                1811
# 8281     4157862               NaN  Newcastle-upon-Tyne                1867
# 8282     4158088               NaN               London                1838
# 8283     4158128               NaN                Derby            1831, 32
# 8284     4159563               NaN               London           [1806]-22
# 8285     4159587               NaN  Newcastle upon Tyne                1834
# 8286     4160339               NaN               London             1834-43
#
#                     Publisher  \
# 8277        John Wiley & Sons
# 8278           Trübner & Co.
# 8279      G. P. Putnam's Sons
# 8280   F. C. and J. Rivington
# 8281               T. Fordyce
# 8282                      NaN
# 8283          M. Mozley & Son
# 8284  T. Cadell and W. Davies
# 8285         Mackenzie & Dent
# 8286                      NaN
#
#                                                   Title  \
# 8277  Third Appendix to the fifth edition of Dana's ...
# 8278  A System of Mineralogy ... Fifth edition, rewr...
# 8279  History of the People of the Netherlands ... T...
# 8280  The New Chronicles of England and France, in t...
# 8281  Local Records; or, Historical Register of rema...
# 8282  The Parochial History of Cornwall, founded on,...
# 8283  The History and Gazetteer of the County of Der...
# 8284  Magna Britannia; being a concise topographical...
# 8285  An historical, topographical and descriptive v...
# 8286  Collectanea Topographica et Genealogica. [Firs...
#
#                                                  Author  \
# 8277                                DANA, James Dwight.
# 8278                                DANA, James Dwight.
# 8279                                BLOK, Pieter Johan.
# 8280                                    FABYAN, Robert.
# 8281      FORDYCE, T. - Printer, of Newcastle-upon-Tyne
# 8282                 GIDDY, afterwards GILBERT, Davies.
# 8283                         GLOVER, Stephen - of Derby
# 8284  LYSONS, Daniel - M.A., F.R.S., and LYSONS (Sam...
# 8285                              Mackenzie, E. (Eneas)
# 8286                                                NaN
#
#                                            Contributors  Corporate Author  \
# 8277                            DANA, Edward Salisbury.               NaN
# 8278      BRUSH, George Jarvis.|DANA, Edward Salisbury.               NaN
# 8279                  BIERSTADT, Oscar A.|PUTNAM, Ruth.               NaN
# 8280  ELLIS, Henry - Sir, Principal Librarian of the...               NaN
# 8281   SYKES, John - Bookseller, of Newcastle-upon-Tyne               NaN
# 8282  BOASE, Henry Samuel.|HALS, William.|LYSONS, Da...               NaN
# 8283                                     NOBLE, Thomas.               NaN
# 8284           GREGSON, Matthew.|LYSONS, Samuel - F.R.S               NaN
# 8285                               ROSS, M. - of Durham               NaN
# 8286            BANDINEL, Bulkeley.|Nichols, John Gough               NaN
#
#       Corporate Contributors Former owner  Engraver Issuance type  \
# 8277                     NaN          NaN       NaN   monographic
# 8278                     NaN          NaN       NaN   monographic
# 8279                     NaN          NaN       NaN   monographic
# 8280                     NaN          NaN       NaN   monographic
# 8281                     NaN          NaN       NaN   monographic
# 8282                     NaN          NaN       NaN   monographic
# 8283                     NaN          NaN       NaN   monographic
# 8284                     NaN          NaN       NaN   monographic
# 8285                     NaN          NaN       NaN   monographic
# 8286                     NaN          NaN       NaN    continuing
#
#                                              Flickr URL  \
# 8277  http://www.flickr.com/photos/britishlibrary/ta...
# 8278  http://www.flickr.com/photos/britishlibrary/ta...
# 8279  http://www.flickr.com/photos/britishlibrary/ta...
# 8280  http://www.flickr.com/photos/britishlibrary/ta...
# 8281  http://www.flickr.com/photos/britishlibrary/ta...
# 8282  http://www.flickr.com/photos/britishlibrary/ta...
# 8283  http://www.flickr.com/photos/britishlibrary/ta...
# 8284  http://www.flickr.com/photos/britishlibrary/ta...
# 8285  http://www.flickr.com/photos/britishlibrary/ta...
# 8286  http://www.flickr.com/photos/britishlibrary/ta...
#
#                                              Shelfmarks
# 8277                   British Library HMNTS 7106.h.13.
# 8278                  British Library HMNTS 07108.i.14.
# 8279  British Library HMNTS|British Library HMNTS 09...
# 8280  British Library HMNTS|British Library HMNTS 19...
# 8281  British Library HMNTS|British Library HMNTS 01...
# 8282  British Library HMNTS|British Library HMNTS 10...
# 8283  British Library HMNTS|British Library HMNTS 10...
# 8284  British Library HMNTS|British Library HMNTS 19...
# 8285  British Library HMNTS|British Library HMNTS 10...
# 8286  British Library HMNTS|British Library HMNTS 79...

# %%
# to see shape of data
df.shape
# Out:
# (8287, 15)

# %%
#to see stastics informations
df.describe()
# Out:
#          Identifier  Corporate Author  Corporate Contributors  Engraver
# count  8.287000e+03               0.0                     0.0       0.0
# mean   2.017344e+06               NaN                     NaN       NaN
# std    1.190379e+06               NaN                     NaN       NaN
# min    2.060000e+02               NaN                     NaN       NaN
# 25%    9.157875e+05               NaN                     NaN       NaN
# 50%    2.043707e+06               NaN                     NaN       NaN
# 75%    3.047430e+06               NaN                     NaN       NaN
# max    4.160339e+06               NaN                     NaN       NaN

# %%
# to see metadata
df.info
# Out:
# <bound method DataFrame.info of       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# 0            1879 [1878]         S. Tinsley & Co.
# 1                   1868             Virtue & Co.
# 2                   1869    Bradbury, Evans & Co.
# 3                   1851            James Darling
# 4                   1857     Wertheim & Macintosh
# ...                  ...                      ...
# 8282                1838                      NaN
# 8283            1831, 32          M. Mozley & Son
# 8284           [1806]-22  T. Cadell and W. Davies
# 8285                1834         Mackenzie & Dent
# 8286             1834-43                      NaN
#
#                                                   Title  \
# 0                     Walter Forbes. [A novel.] By A. A
# 1     All for Greed. [A novel. The dedication signed...
# 2     Love the Avenger. By the author of “All for Gr...
# 3     Welsh Sketches, chiefly ecclesiastical, to the...
# 4     [The World in which I live, and my place in it...
# ...                                                 ...
# 8282  The Parochial History of Cornwall, founded on,...
# 8283  The History and Gazetteer of the County of Der...
# 8284  Magna Britannia; being a concise topographical...
# 8285  An historical, topographical and descriptive v...
# 8286  Collectanea Topographica et Genealogica. [Firs...
#
#                                                  Author  \
# 0                                                 A. A.
# 1                                             A., A. A.
# 2                                             A., A. A.
# 3                                             A., E. S.
# 4                                             A., E. S.
# ...                                                 ...
# 8282                 GIDDY, afterwards GILBERT, Davies.
# 8283                         GLOVER, Stephen - of Derby
# 8284  LYSONS, Daniel - M.A., F.R.S., and LYSONS (Sam...
# 8285                              Mackenzie, E. (Eneas)
# 8286                                                NaN
#
#                                            Contributors  Corporate Author  \
# 0                                       FORBES, Walter.               NaN
# 1          BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2          BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3                           Appleyard, Ernest Silvanus.               NaN
# 4                                   BROOME, John Henry.               NaN
# ...                                                 ...               ...
# 8282  BOASE, Henry Samuel.|HALS, William.|LYSONS, Da...               NaN
# 8283                                     NOBLE, Thomas.               NaN
# 8284           GREGSON, Matthew.|LYSONS, Samuel - F.R.S               NaN
# 8285                               ROSS, M. - of Durham               NaN
# 8286            BANDINEL, Bulkeley.|Nichols, John Gough               NaN
#
#       Corporate Contributors Former owner  Engraver Issuance type  \
# 0                        NaN          NaN       NaN   monographic
# 1                        NaN          NaN       NaN   monographic
# 2                        NaN          NaN       NaN   monographic
# 3                        NaN          NaN       NaN   monographic
# 4                        NaN          NaN       NaN   monographic
# ...                      ...          ...       ...           ...
# 8282                     NaN          NaN       NaN   monographic
# 8283                     NaN          NaN       NaN   monographic
# 8284                     NaN          NaN       NaN   monographic
# 8285                     NaN          NaN       NaN   monographic
# 8286                     NaN          NaN       NaN    continuing
#
#                                              Flickr URL  \
# 0     http://www.flickr.com/photos/britishlibrary/ta...
# 1     http://www.flickr.com/photos/britishlibrary/ta...
# 2     http://www.flickr.com/photos/britishlibrary/ta...
# 3     http://www.flickr.com/photos/britishlibrary/ta...
# 4     http://www.flickr.com/photos/britishlibrary/ta...
# ...                                                 ...
# 8282  http://www.flickr.com/photos/britishlibrary/ta...
# 8283  http://www.flickr.com/photos/britishlibrary/ta...
# 8284  http://www.flickr.com/photos/britishlibrary/ta...
# 8285  http://www.flickr.com/photos/britishlibrary/ta...
# 8286  http://www.flickr.com/photos/britishlibrary/ta...
#
#                                              Shelfmarks
# 0                     British Library HMNTS 12641.b.30.
# 1                     British Library HMNTS 12626.cc.2.
# 2                     British Library HMNTS 12625.dd.1.
# 3                   British Library HMNTS 10369.bbb.15.
# 4                      British Library HMNTS 9007.d.28.
# ...                                                 ...
# 8282  British Library HMNTS|British Library HMNTS 10...
# 8283  British Library HMNTS|British Library HMNTS 10...
# 8284  British Library HMNTS|British Library HMNTS 19...
# 8285  British Library HMNTS|British Library HMNTS 10...
# 8286  British Library HMNTS|British Library HMNTS 79...
#
# [8287 rows x 15 columns]>

# %%
# to see in short form and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Identifier              8287 non-null   int64
#  1   Edition Statement       773 non-null    object
#  2   Place of Publication    8287 non-null   object
#  3   Date of Publication     8106 non-null   object
#  4   Publisher               4092 non-null   object
#  5   Title                   8287 non-null   object
#  6   Author                  6509 non-null   object
#  7   Contributors            8287 non-null   object
#  8   Corporate Author        0 non-null      float64
#  9   Corporate Contributors  0 non-null      float64
#  10  Former owner            1 non-null      object
#  11  Engraver                0 non-null      float64
#  12  Issuance type           8287 non-null   object
#  13  Flickr URL              8287 non-null   object
#  14  Shelfmarks              8287 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 971.3+ KB

# %%
# to see columns name
df.columns
# Out:
# Index(['Identifier', 'Edition Statement', 'Place of Publication',
#        'Date of Publication', 'Publisher', 'Title', 'Author', 'Contributors',
#        'Corporate Author', 'Corporate Contributors', 'Former owner',
#        'Engraver', 'Issuance type', 'Flickr URL', 'Shelfmarks'],
#       dtype='object')

# %%
# Replace whitespace in column names with underscores
df.columns = df.columns.str.replace(" ", "_")
df
# Out:
#       Identifier             Edition_Statement      Place_of_Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date_of_Publication                Publisher  \
# 0            1879 [1878]         S. Tinsley & Co.
# 1                   1868             Virtue & Co.
# 2                   1869    Bradbury, Evans & Co.
# 3                   1851            James Darling
# 4                   1857     Wertheim & Macintosh
# ...                  ...                      ...
# 8282                1838                      NaN
# 8283            1831, 32          M. Mozley & Son
# 8284           [1806]-22  T. Cadell and W. Davies
# 8285                1834         Mackenzie & Dent
# 8286             1834-43                      NaN
#
#                                                   Title  \
# 0                     Walter Forbes. [A novel.] By A. A
# 1     All for Greed. [A novel. The dedication signed...
# 2     Love the Avenger. By the author of “All for Gr...
# 3     Welsh Sketches, chiefly ecclesiastical, to the...
# 4     [The World in which I live, and my place in it...
# ...                                                 ...
# 8282  The Parochial History of Cornwall, founded on,...
# 8283  The History and Gazetteer of the County of Der...
# 8284  Magna Britannia; being a concise topographical...
# 8285  An historical, topographical and descriptive v...
# 8286  Collectanea Topographica et Genealogica. [Firs...
#
#                                                  Author  \
# 0                                                 A. A.
# 1                                             A., A. A.
# 2                                             A., A. A.
# 3                                             A., E. S.
# 4                                             A., E. S.
# ...                                                 ...
# 8282                 GIDDY, afterwards GILBERT, Davies.
# 8283                         GLOVER, Stephen - of Derby
# 8284  LYSONS, Daniel - M.A., F.R.S., and LYSONS (Sam...
# 8285                              Mackenzie, E. (Eneas)
# 8286                                                NaN
#
#                                            Contributors  Corporate_Author  \
# 0                                       FORBES, Walter.               NaN
# 1          BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2          BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3                           Appleyard, Ernest Silvanus.               NaN
# 4                                   BROOME, John Henry.               NaN
# ...                                                 ...               ...
# 8282  BOASE, Henry Samuel.|HALS, William.|LYSONS, Da...               NaN
# 8283                                     NOBLE, Thomas.               NaN
# 8284           GREGSON, Matthew.|LYSONS, Samuel - F.R.S               NaN
# 8285                               ROSS, M. - of Durham               NaN
# 8286            BANDINEL, Bulkeley.|Nichols, John Gough               NaN
#
#       Corporate_Contributors Former_owner  Engraver Issuance_type  \
# 0                        NaN          NaN       NaN   monographic
# 1                        NaN          NaN       NaN   monographic
# 2                        NaN          NaN       NaN   monographic
# 3                        NaN          NaN       NaN   monographic
# 4                        NaN          NaN       NaN   monographic
# ...                      ...          ...       ...           ...
# 8282                     NaN          NaN       NaN   monographic
# 8283                     NaN          NaN       NaN   monographic
# 8284                     NaN          NaN       NaN   monographic
# 8285                     NaN          NaN       NaN   monographic
# 8286                     NaN          NaN       NaN    continuing
#
#                                              Flickr_URL  \
# 0     http://www.flickr.com/photos/britishlibrary/ta...
# 1     http://www.flickr.com/photos/britishlibrary/ta...
# 2     http://www.flickr.com/photos/britishlibrary/ta...
# 3     http://www.flickr.com/photos/britishlibrary/ta...
# 4     http://www.flickr.com/photos/britishlibrary/ta...
# ...                                                 ...
# 8282  http://www.flickr.com/photos/britishlibrary/ta...
# 8283  http://www.flickr.com/photos/britishlibrary/ta...
# 8284  http://www.flickr.com/photos/britishlibrary/ta...
# 8285  http://www.flickr.com/photos/britishlibrary/ta...
# 8286  http://www.flickr.com/photos/britishlibrary/ta...
#
#                                              Shelfmarks
# 0                     British Library HMNTS 12641.b.30.
# 1                     British Library HMNTS 12626.cc.2.
# 2                     British Library HMNTS 12625.dd.1.
# 3                   British Library HMNTS 10369.bbb.15.
# 4                      British Library HMNTS 9007.d.28.
# ...                                                 ...
# 8282  British Library HMNTS|British Library HMNTS 10...
# 8283  British Library HMNTS|British Library HMNTS 10...
# 8284  British Library HMNTS|British Library HMNTS 19...
# 8285  British Library HMNTS|British Library HMNTS 10...
# 8286  British Library HMNTS|British Library HMNTS 79...
#
# [8287 rows x 15 columns]

# %% [markdown]
# As per my observation i identify some error in data:
#
# 1- columns name has whitespaces
#
# 2- colums Edition Statement, Corporate Author, Corporate Contributors, Former owner, Engraver
#
# ['Edition Statement',
# ...            'Corporate Author',
# ...            'Corporate Contributors',
# ...            'Former owner',
# ...            'Engraver',
# ...            'Contributors',
# ...            'Issuance type',
# ...            'Shelfmarks']

# %%
# now deling with null values ( NaN) related columns
# we can drop columns from the dateset when it has more then 80% has null values or even when column data is not relavant
drop_df=df.drop(['Edition_Statement','Title', 'Author','Contributors','Corporate_Author','Corporate_Contributors','Former_owner',
       'Engraver','Issuance_type',  'Shelfmarks'],
      axis=1)

# %%
drop_df.columns
# Out:
# Index(['Identifier', 'Place_of_Publication', 'Date_of_Publication',
#        'Publisher', 'Flickr_URL'],
#       dtype='object')

# %%
#to check any null values
drop_df.notnull()
# Out:
#       Identifier  Place_of_Publication  Date_of_Publication  Publisher  \
# 0           True                  True                 True       True
# 1           True                  True                 True       True
# 2           True                  True                 True       True
# 3           True                  True                 True       True
# 4           True                  True                 True       True
# ...          ...                   ...                  ...        ...
# 8282        True                  True                 True      False
# 8283        True                  True                 True       True
# 8284        True                  True                 True       True
# 8285        True                  True                 True       True
# 8286        True                  True                 True      False
#
#       Flickr_URL
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ...          ...
# 8282        True
# 8283        True
# 8284        True
# 8285        True
# 8286        True
#
# [8287 rows x 5 columns]

# %%
#In databases, indexing is used to speed up access to data. By creating an index of the data, the database can quickly find the desired information without having to scan the entire database.
drop_df['Identifier'].is_unique
# Out:
# True

# %%
#we can use "Identifier" as index for getting data
drop_df = drop_df.set_index('Identifier')
drop_df.head()
# Out:
#                 Place_of_Publication Date_of_Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                    Flickr_URL
# Identifier
# 206         http://www.flickr.com/photos/britishlibrary/ta...
# 216         http://www.flickr.com/photos/britishlibrary/ta...
# 218         http://www.flickr.com/photos/britishlibrary/ta...
# 472         http://www.flickr.com/photos/britishlibrary/ta...
# 480         http://www.flickr.com/photos/britishlibrary/ta...

# %% [markdown]
# The code df.set_index('Identifier', inplace=True) sets the Identifier column as the index of the DataFrame df. The inplace=True parameter tells Pandas to modify the existing DataFrame instead of creating a new one.
#
# When a column is set as the index, it is no longer considered a column in the DataFrame. Instead, it becomes the row labels. This means that you can access the rows in the DataFrame by their Identifier values, instead of their row numbers.

# %% [markdown]
# loc() and iloc() are two methods in Pandas that are used to select rows and columns from a DataFrame. They are very similar, but there are some key differences between them.
#
# loc() is label-based indexing, while iloc() is integer-based indexing. This means that loc() uses the row and column names to select data, while iloc() uses the row and column indexes.

# %%
#using loc{key_based} select the raw
drop_df.loc[206]
# Out:
# Place_of_Publication                                               London
# Date_of_Publication                                           1879 [1878]
# Publisher                                                S. Tinsley & Co.
# Flickr_URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 206, dtype: object

# %%
# usig iloc[ index] or entry based select the raw
drop_df.iloc[1]
# Out:
# Place_of_Publication                             London; Virtue & Yorston
# Date_of_Publication                                                  1868
# Publisher                                                    Virtue & Co.
# Flickr_URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 216, dtype: object

# %% [markdown]
# The df.get_dtype_counts() method in Pandas returns a Series object that contains the count of each data type in the DataFrame df. The Series object has the data type dtype and the index is the name of the data type.

# %%
drop_df.get_dtype_count()

# %%
#now try to clean date_of_publication coulunms values
drop_df.loc[1905:, 'Date_of_Publication'].head(10)
# Out:
# Identifier
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# 2956        1860-63
# 2957           1873
# 3017           1866
# 3131           1899
# 4598           1814
# 4884           1820
# Name: Date_of_Publication, dtype: object

# %%
regex = r'^(\d{4})'
extr = drop_df['Date_of_Publication'].str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date_of_Publication, dtype: object

# %% [markdown]
# The code regex = r'^(\d{4})' defines a regular expression that matches a four-digit number at the beginning of a string. The \d metacharacter matches any digit, and the {4} quantifier matches the previous metacharacter four times.
#
# The code extr = df['Date of Publication'].str.extract(r'^(\d{4})', expand=False) uses the str.extract() method to extract the four-digit number from the Date of Publication column in the DataFrame df. The expand=False parameter tells Pandas to return a Series object with the extracted values, instead of expanding the Series object to a DataFrame with one column for each extracted value.
#
# The code extr.head() prints the first five rows of the Series object extr.

# %%
#convert these to a numeric type and copy them back:
drop_df['Date_of_Publication'] = pd.to_numeric(extr)
drop_df['Date_of_Publication'].dtype
# Out:
# dtype('float64')

# %%
#cleaning the place of publication column
drop_df['Place_of_Publication'].head(10)
# Out:
# Identifier
# 206                                  London
# 216                London; Virtue & Yorston
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667     pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                 London]
# 1143                                 London
# Name: Place_of_Publication, dtype: object

# %%
pob = drop_df['Place_of_Publication']
London = pob.str.contains('London')
London[:5]
# Out:
# Identifier
# 206    True
# 216    True
# 218    True
# 472    True
# 480    True
# Name: Place_of_Publication, dtype: bool

# %% [markdown]
# Sure, I can help you with that.
#
# The code pub = df['Place of Publication'] creates a new variable called pub that contains the Place of Publication column from the DataFrame df.
#
# The code london = pub.str.contains('London') uses the str.contains() method to check if the Place of Publication column contains the string "London". The str.contains() method returns a Boolean Series object, where each value is True if the corresponding value in the Place of Publication column contains the string "London" and False otherwise.
#
# The code london[:5] prints the first 5 values of the Boolean Series object london.

# %%
# to save clean data in csv formate
df.to_csv("clean_data.csv")

# %%
oxford = pob.str.contains('Oxford')
drop_df['Place_of_Publication'] = np.where(London, 'London',
                                    np.where(oxford, 'Oxford',
                                            pob.str.replace('-', ' ')))
drop_df['Place_of_Publication'].head()
# Out:
# Identifier
# 206    London
# 216    London
# 218    London
# 472    London
# 480    London
# Name: Place_of_Publication, dtype: object

# %%
drop_df['Publisher']
# Out:
# Identifier
# 206               S. Tinsley & Co.
# 216                   Virtue & Co.
# 218          Bradbury, Evans & Co.
# 472                  James Darling
# 480           Wertheim & Macintosh
#                     ...
# 4158088                        NaN
# 4158128            M. Mozley & Son
# 4159563    T. Cadell and W. Davies
# 4159587           Mackenzie & Dent
# 4160339                        NaN
# Name: Publisher, Length: 8287, dtype: object

# %%
drop_df["Publisher"] =str(drop_df["Publisher"])
drop_df["Publisher"] =drop_df["Publisher"].map(str.strip)

# %% [markdown]
# The code df["Publisher"] = df["Publisher"].map(str.strip) uses the map() function to apply the str.strip() method to the Publisher column in the DataFrame df. The str.strip() method removes any leading and trailing whitespace from a string.

# %%
# reading the another files
olympics_df=pd.read_csv('https://raw.githubusercontent.com/mramshaw/Data-Cleaning/master/Datasets/olympics.csv',header=1)
olympics_df
# Out:
#                                        Unnamed: 0  ? Summer  01 !  02 !  03 !  \
# 0                               Afghanistan (AFG)        13     0     0     2
# 1                                   Algeria (ALG)        12     5     2     8
# 2                                 Argentina (ARG)        23    18    24    28
# 3                                   Armenia (ARM)         5     1     2     9
# 4                         Australasia (ANZ) [ANZ]         2     3     4     5
# ..                                            ...       ...   ...   ...   ...
# 142  Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# 143                            Zambia (ZAM) [ZAM]        12     0     1     1
# 144                          Zimbabwe (ZIM) [ZIM]        12     3     4     1
# 145                        Mixed team (ZZX) [ZZX]         3     8     5     4
# 146                                        Totals        27  4809  4775  5130
#
#      Total  ? Winter  01 !.1  02 !.1  03 !.1  Total.1  ? Games  01 !.2  \
# 0        2         0       0       0       0        0       13       0
# 1       15         3       0       0       0        0       15       5
# 2       70        18       0       0       0        0       41      18
# 3       12         6       0       0       0        0       11       1
# 4       12         0       0       0       0        0        2       3
# ..     ...       ...     ...     ...     ...      ...      ...     ...
# 142      3         0       0       0       0        0        1       0
# 143      2         0       0       0       0        0       12       0
# 144      8         1       0       0       0        0       13       3
# 145     17         0       0       0       0        0        3       8
# 146  14714        22     959     958     948     2865       49    5768
#
#      02 !.2  03 !.2  Combined total
# 0         0       2               2
# 1         2       8              15
# 2        24      28              70
# 3         2       9              12
# 4         4       5              12
# ..      ...     ...             ...
# 142       1       2               3
# 143       1       1               2
# 144       4       1               8
# 145       5       4              17
# 146    5733    6078           17579
#
# [147 rows x 16 columns]

# %% [markdown]
# here we can see columns names are not writen in proper

# %%
new_names={'Unnamed: 0': 'Country','? Summer': 'Summer Olympics','01 !': 'Gold','02 !': 'Silver','03 !': 'Bronze','? Winter': 'Winter Olympics','01 !.1': 'Gold.1','02 !.1': 'Silver.1','03 !.1': 'Bronze.1','? Games': '# Games','01 !.2': 'Gold.2','02 !.2': 'Silver.2','03 !.2': 'Bronze.2'}

olympics_df.rename(columns=new_names, inplace=True)
olympics_df.head()
# Out:
#                    Country  Summer Olympics  Gold  Silver  Bronze  Total  \
# 0        Afghanistan (AFG)               13     0       0       2      2
# 1            Algeria (ALG)               12     5       2       8     15
# 2          Argentina (ARG)               23    18      24      28     70
# 3            Armenia (ARM)                5     1       2       9     12
# 4  Australasia (ANZ) [ANZ]                2     3       4       5     12
#
#    Winter Olympics  Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# 0                0       0         0         0        0       13       0
# 1                3       0         0         0        0       15       5
# 2               18       0         0         0        0       41      18
# 3                6       0         0         0        0       11       1
# 4                0       0         0         0        0        2       3
#
#    Silver.2  Bronze.2  Combined total
# 0         0         2               2
# 1         2         8              15
# 2        24        28              70
# 3         2         9              12
# 4         4         5              12

# %% [markdown]
# Using the columns attribute: The columns attribute is a list of the column names in a DataFrame. You can use this attribute to rename the columns by assigning a new list of column names to it. For example, the following code renames the columns in the DataFrame df to the following:
